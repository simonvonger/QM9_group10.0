# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('HOMO.out')
df_train_loss = pd.DataFrame(columns=df.columns)

for i in range(len(df)):
    if 'Current loss' in df.iloc[i, 0]:
        # Extract only the numbers after 'is'
        number = df.iloc[i, 0].split('loss')[-1].strip().split(' ')[0]
        df_train_loss = pd.concat([df_train_loss, pd.DataFrame({'training_loss': [float(number)]})], ignore_index=True)

# average for every 11 rows
df_train_loss = df_train_loss.groupby(df_train_loss.index // 11).mean()

df_validation_loss = pd.DataFrame(columns=df.columns)

for i in range(len(df)):
    if 'is' in df.iloc[i, 0]:
        # Extract only the numbers after 'is'
        number = df.iloc[i, 0].split('is')[-1].strip()
        df_validation_loss = pd.concat([df_validation_loss, pd.DataFrame({'validation_loss': [float(number)]})], ignore_index=True)

# make a df with both training and validation loss
df_loss = pd.concat([df_train_loss, df_validation_loss], axis=1)

# drop columns 'cuda will be used for training the PaiNN model' and 'cuda will be used for training the PaiNN model'
df_loss.drop(columns=['cuda will be used for training the PaiNN model', 'cuda will be used for training the PaiNN model'], inplace=True)

# Plot using seaborn
sns.lineplot(data=df_loss)

# x-axis
plt.xlabel('Epoch')
# y-axis
plt.ylabel('Mean Squared Error')
plt.title('Loss for PaiNN model using HOMO energy')
# set the y-axis range from 0 to 1
plt.ylim(0, 0.45)
plt.xlim(0,100)

# Save the plot as PNG
plt.savefig('HOMO_loss.png')

# Show the plot
plt.show()
# Out:
# C:\Users\vonge\AppData\Local\Temp\ipykernel_11420\1602243589.py:15: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_train_loss = df_train_loss.groupby(df_train_loss.index // 11).mean()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('LUMO.out')
df_train_loss = pd.DataFrame(columns=df.columns)

for i in range(len(df)):
    if 'Current loss' in df.iloc[i, 0]:
        # Extract only the numbers after 'is'
        number = df.iloc[i, 0].split('loss')[-1].strip().split(' ')[0]
        df_train_loss = pd.concat([df_train_loss, pd.DataFrame({'training_loss': [float(number)]})], ignore_index=True)

# average for every 11 rows
df_train_loss = df_train_loss.groupby(df_train_loss.index // 11).mean()

df_validation_loss = pd.DataFrame(columns=df.columns)

for i in range(len(df)):
    if 'is' in df.iloc[i, 0]:
        # Extract only the numbers after 'is'
        number = df.iloc[i, 0].split('is')[-1].strip()
        df_validation_loss = pd.concat([df_validation_loss, pd.DataFrame({'validation_loss': [float(number)]})], ignore_index=True)

# make a df with both training and validation loss
df_loss = pd.concat([df_train_loss, df_validation_loss], axis=1)

# drop columns 'cuda will be used for training the PaiNN model' and 'cuda will be used for training the PaiNN model'
df_loss.drop(columns=['cuda will be used for training the PaiNN model', 'cuda will be used for training the PaiNN model'], inplace=True)

# Plot using seaborn
sns.lineplot(data=df_loss)

# x-axis
plt.xlabel('Epoch')
# y-axis
plt.ylabel('Mean Squared Error')
plt.title('Loss for PaiNN model using LUMO energy')
# set the y-axis range from 0 to 1
plt.ylim(0, 0.45)
plt.xlim(0,100)

# Save the plot as PNG
plt.savefig('LUMO_plot.png')

# Show the plot
plt.show()
# Out:
# C:\Users\vonge\AppData\Local\Temp\ipykernel_11420\2745173690.py:15: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_train_loss = df_train_loss.groupby(df_train_loss.index // 11).mean()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('alpha.out')
df_train_loss = pd.DataFrame(columns=df.columns)

for i in range(len(df)):
    if 'Current loss' in df.iloc[i, 0]:
        # Extract only the numbers after 'is'
        number = df.iloc[i, 0].split('loss')[-1].strip().split(' ')[0]
        df_train_loss = pd.concat([df_train_loss, pd.DataFrame({'training_loss': [float(number)]})], ignore_index=True)

# average for every 11 rows
df_train_loss = df_train_loss.groupby(df_train_loss.index // 11).mean()

df_validation_loss = pd.DataFrame(columns=df.columns)

for i in range(len(df)):
    if 'is' in df.iloc[i, 0]:
        # Extract only the numbers after 'is'
        number = df.iloc[i, 0].split('is')[-1].strip()
        df_validation_loss = pd.concat([df_validation_loss, pd.DataFrame({'validation_loss': [float(number)]})], ignore_index=True)

# make a df with both training and validation loss
df_loss = pd.concat([df_train_loss, df_validation_loss], axis=1)

# drop columns 'cuda will be used for training the PaiNN model' and 'cuda will be used for training the PaiNN model'
df_loss.drop(columns=['cuda will be used for training the PaiNN model', 'cuda will be used for training the PaiNN model'], inplace=True)

# Plot using seaborn
sns.lineplot(data=df_loss)

# x-axis
plt.xlabel('Epoch')
# y-axis
plt.ylabel('Mean Squared Error')
plt.title('Loss for PaiNN model using alpha')
# set the y-axis range from 0 to 1
plt.ylim(0, 3)
plt.xlim(0,100)

# Save the plot as PNG
plt.savefig('alpha.png')

# Show the plot
plt.show()
# Out:
# C:\Users\vonge\AppData\Local\Temp\ipykernel_11420\3481486089.py:15: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_train_loss = df_train_loss.groupby(df_train_loss.index // 11).mean()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('zpve.out')
df_train_loss = pd.DataFrame(columns=df.columns)

for i in range(len(df)):
    if 'Current loss' in df.iloc[i, 0]:
        # Extract only the numbers after 'is'
        number = df.iloc[i, 0].split('loss')[-1].strip().split(' ')[0]
        df_train_loss = pd.concat([df_train_loss, pd.DataFrame({'training_loss': [float(number)]})], ignore_index=True)

# average for every 11 rows
df_train_loss = df_train_loss.groupby(df_train_loss.index // 11).mean()

df_validation_loss = pd.DataFrame(columns=df.columns)

for i in range(len(df)):
    if 'is' in df.iloc[i, 0]:
        # Extract only the numbers after 'is'
        number = df.iloc[i, 0].split('is')[-1].strip()
        df_validation_loss = pd.concat([df_validation_loss, pd.DataFrame({'validation_loss': [float(number)]})], ignore_index=True)

# make a df with both training and validation loss
df_loss = pd.concat([df_train_loss, df_validation_loss], axis=1)

# drop columns 'cuda will be used for training the PaiNN model' and 'cuda will be used for training the PaiNN model'
df_loss.drop(columns=['cuda will be used for training the PaiNN model', 'cuda will be used for training the PaiNN model'], inplace=True)

# Plot using seaborn
sns.lineplot(data=df_loss)

# x-axis
plt.xlabel('Epoch')
# y-axis
plt.ylabel('Mean Squared Error')
plt.title('Loss for PaiNN model using zpve')
# set the y-axis range from 0 to 1
plt.ylim(0, 0.005)
plt.xlim(0,30)

# Save the plot as PNG
plt.savefig('zpve.png')

# Show the plot
plt.show()
# Out:
# C:\Users\vonge\AppData\Local\Temp\ipykernel_11420\3294159668.py:15: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_train_loss = df_train_loss.groupby(df_train_loss.index // 11).mean()

# %%
from PIL import Image

# List of PNG files to combine
file_names = ['HOMO_loss.png', 'LUMO_plot.png', 'alpha.png', 'zpve.png']

# Open each image
images = [Image.open(file_name) for file_name in file_names]

# Get the size of each image
widths, heights = zip(*(i.size for i in images))

# Calculate the total size of the combined image
total_width = max(widths) * 2
total_height = max(heights) * 2

# Create a new image with white background
combined_image = Image.new('RGB', (total_width, total_height), 'white')

# Paste each image into the combined image
for i in range(len(images)):
    x_offset = (i % 2) * max(widths)
    y_offset = (i // 2) * max(heights)
    combined_image.paste(images[i], (x_offset, y_offset))

# Save the combined image
combined_image.save('combined_loss_plots.png')
